# %% [markdown]
# <a href="https://colab.research.google.com/github/j-chenn/COMP551_Project_1/blob/main/COMP551_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: Acquire, pre-process and analyze the data
# ## Acquiring both datasets:
# Dataset 1: [Search Trends](https://github.com/google-research/open-covid-19-data/blob/master/data/exports/search_trends_symptoms_dataset/README.mdhttps://)
#
# Dataset 2: [COVID hospitalization cases](https://github.com/google-research/open-covid-19-data)

# %%
# Imports

import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# the week of 08/24/2020 for the data collection
# Load into pandas dataframes
st_df = pd.read_csv('2020_US_weekly_symptoms_dataset.csv', low_memory=False)
hp_df = pd.read_csv('aggregated_cc_by.csv', low_memory=False)

# %% [markdown]
# ## Preprocess the datasets

# %% [markdown]
# ## Target Weeks range: 2020-03-09 to 2020-09-21

# %%
# Search trends dataset Part I

#TODO: Preprocessing, remove all symptoms that have all zero entries (clean COLUMN)
st_df = st_df.dropna(how='all', axis=1)

#Remove all rows not in the date of the week chosen (clean ROW)
st_df = st_df[st_df['date'] >= '2020-03-04']

nameList = list(st_df['sub_region_1']) #extract the region names from st_df database
nameList = list(dict.fromkeys(nameList))  #remove duplicates

# %%
# Hospitalization dataset Part I

#TODO: Preprocessing

#keep the hospitalization features and delete the rest  (clean COLUMN)
hp_df = hp_df[['open_covid_region_code','region_name','date', 'hospitalized_new']]

#select the regions that match the Search trends dataset (clean ROW)
hp_df= hp_df[hp_df.region_name.isin(nameList)]

#select the regions that have the valid date range (clean ROW)
hp_df = hp_df[(hp_df['date'] >= '2020-03-09') & (hp_df['date'] <= '2020-09-27')]

hp_df.reset_index(inplace = True) 
#print(hp_df.to_string())

# %%
# Hospitalization dataset Part II
# Here we want to group dates in the same week together as one date (the weekdate)
hp_df1 = hp_df
weekdate = '2020-03-09'

#This loop will update all the dates row by row
for i, n in hp_df1.iterrows():
    if (i%7 == 0):
        weekdate = n['date']  #first date of the week
    else:
        hp_df1.at[i,'date'] = weekdate

# %%
#sum up the hospitalized_vew for weekly
# we are only using this hp_df2 to rid regions that have insignificant hospitalized data, such as 0 for total hospitalization
def cleanRegions(df):
    hp_df2 = df
    f = dict.fromkeys(hp_df2.columns.difference(['region_name']), 'first')
    f['hospitalized_new'] = sum
    hp_df2 = hp_df2.groupby('region_name', as_index=False).agg(f)
    hp_df2 = hp_df2[hp_df2.hospitalized_new != 0]
    print(hp_df2.to_string())
    tmplist = list(hp_df2['region_name']) 
    tmplist = list(dict.fromkeys(tmplist))  
    return(tmplist)

#this nameList will be a new regions list that removes region with total of 0 hospitalization value for all its dates
nameList2 = cleanRegions(hp_df1)

#filter hp_df1 based on the nameList2 (clean ROW)
hp_df2= hp_df1[hp_df1.region_name.isin(nameList2)]
# Out:
#       region_name        date  hospitalized_new  index open_covid_region_code
# 3          Hawaii  2020-03-09             802.0  87097                  US-HI
# 4           Idaho  2020-03-09            1811.0  86678                  US-ID
# 5           Maine  2020-03-09             445.0  84953                  US-ME
# 6         Montana  2020-03-09             687.0  83701                  US-MT
# 7        Nebraska  2020-03-09            2279.0  83071                  US-NE
# 8   New Hampshire  2020-03-09             736.0  82860                  US-NH
# 9      New Mexico  2020-03-09            3435.0  82413                  US-NM
# 10   North Dakota  2020-03-09             815.0  83280                  US-ND
# 11   Rhode Island  2020-03-09            2725.0  80738                  US-RI
# 12   South Dakota  2020-03-09            1473.0  80311                  US-SD
# 15        Wyoming  2020-03-09             262.0  78166                  US-WY

# %%
# Hospitalization dataset Part III

# merge 7 week rows into 1 and sum up the hospitalized_new data
hp_df3 = hp_df2.groupby(['region_name','date'])['hospitalized_new'].apply(sum).reset_index()

# %%
# Search trends dataset Part II

# Drop unnecessary columns (open_covid region_code, country_region_code, country_region) (clean COLUMN)
st_df1 = st_df.drop(st_df.columns[[0, 1, 2]], axis=1)

# Filter st_df based on nameList2 (clean ROW)
st_df1= st_df1[st_df.sub_region_1.isin(nameList2)]
# print(st_df1)
# print(st_df1.shape)

#Filter columns so that every column have at least sp_num% of non-zero entries  (clean COLUMN)
sp_num = 0.24  #optimized ratio without tremendous loss of dataset
st_df2 = st_df1.dropna(thresh=sp_num*len(st_df), axis=1)
# print("after........." )
# print(st_df2)
# print(st_df2.shape)

# %% [markdown]
# ## Merging the datasets

# %%
hpData = hp_df3["hospitalized_new"]
hpData = pd.Series(hpData)

st_df2['hospitalized_new'] = hpData.values # Merging the data_set
print(st_df2)
# Out:
#      sub_region_1 sub_region_1_code        date  symptom:Adrenal crisis  \
# 123        Hawaii             US-HI  2020-03-09                     NaN
# 124        Hawaii             US-HI  2020-03-16                     NaN
# 125        Hawaii             US-HI  2020-03-23                     NaN
# 126        Hawaii             US-HI  2020-03-30                     NaN
# 127        Hawaii             US-HI  2020-04-06                     NaN
# 128        Hawaii             US-HI  2020-04-13                     NaN
# 129        Hawaii             US-HI  2020-04-20                     NaN
# 130        Hawaii             US-HI  2020-04-27                     NaN
# 131        Hawaii             US-HI  2020-05-04                     NaN
# 132        Hawaii             US-HI  2020-05-11                     NaN
# 133        Hawaii             US-HI  2020-05-18                     NaN
# 134        Hawaii             US-HI  2020-05-25                     NaN
# 135        Hawaii             US-HI  2020-06-01                     NaN
# 136        Hawaii             US-HI  2020-06-08                     NaN
# 137        Hawaii             US-HI  2020-06-15                     NaN
# 138        Hawaii             US-HI  2020-06-22                     NaN
# 139        Hawaii             US-HI  2020-06-29                     NaN
# 140        Hawaii             US-HI  2020-07-06                     NaN
# 141        Hawaii             US-HI  2020-07-13                     NaN
# 142        Hawaii             US-HI  2020-07-20                     NaN
# 143        Hawaii             US-HI  2020-07-27                     NaN
# 144        Hawaii             US-HI  2020-08-03                     NaN
# 145        Hawaii             US-HI  2020-08-10                     NaN
# 146        Hawaii             US-HI  2020-08-17                     NaN
# 147        Hawaii             US-HI  2020-08-24                     NaN
# 148        Hawaii             US-HI  2020-08-31                     NaN
# 149        Hawaii             US-HI  2020-09-07                     NaN
# 150        Hawaii             US-HI  2020-09-14                     NaN
# 151        Hawaii             US-HI  2020-09-21                     NaN
# 161         Idaho             US-ID  2020-03-09                     NaN
# ..            ...               ...         ...                     ...
# 493  South Dakota             US-SD  2020-09-21                   12.27
# 579       Wyoming             US-WY  2020-03-09                    3.71
# 580       Wyoming             US-WY  2020-03-16                    2.94
# 581       Wyoming             US-WY  2020-03-23                     NaN
# 582       Wyoming             US-WY  2020-03-30                    3.07
# 583       Wyoming             US-WY  2020-04-06                    2.73
# 584       Wyoming             US-WY  2020-04-13                    4.49
# 585       Wyoming             US-WY  2020-04-20                    3.45
# 586       Wyoming             US-WY  2020-04-27                     NaN
# 587       Wyoming             US-WY  2020-05-04                    2.88
# 588       Wyoming             US-WY  2020-05-11                    3.93
# 589       Wyoming             US-WY  2020-05-18                    3.42
# 590       Wyoming             US-WY  2020-05-25                    3.27
# 591       Wyoming             US-WY  2020-06-01                     NaN
# 592       Wyoming             US-WY  2020-06-08                    5.56
# 593       Wyoming             US-WY  2020-06-15                    4.57
# 594       Wyoming             US-WY  2020-06-22                    4.64
# 595       Wyoming             US-WY  2020-06-29                    2.76
# 596       Wyoming             US-WY  2020-07-06                    5.40
# 597       Wyoming             US-WY  2020-07-13                    3.94
# 598       Wyoming             US-WY  2020-07-20                    3.67
# 599       Wyoming             US-WY  2020-07-27                    3.44
# 600       Wyoming             US-WY  2020-08-03                    3.08
# 601       Wyoming             US-WY  2020-08-10                    3.19
# 602       Wyoming             US-WY  2020-08-17                    5.95
# 603       Wyoming             US-WY  2020-08-24                    4.42
# 604       Wyoming             US-WY  2020-08-31                    5.03
# 605       Wyoming             US-WY  2020-09-07                    3.36
# 606       Wyoming             US-WY  2020-09-14                    4.15
# 607       Wyoming             US-WY  2020-09-21                    5.64
#
#      symptom:Allergic conjunctivitis  symptom:Angular cheilitis  \
# 123                              NaN                      32.41
# 124                              NaN                      28.68
# 125                              NaN                      31.62
# 126                              NaN                      39.39
# 127                              NaN                      36.26
# 128                              NaN                      47.51
# 129                              NaN                      31.97
# 130                              NaN                      37.96
# 131                              NaN                      38.03
# 132                              NaN                      37.09
# 133                              NaN                      27.92
# 134                              NaN                      46.53
# 135                              NaN                      27.99
# 136                              NaN                      34.94
# 137                              NaN                      37.62
# 138                              NaN                      30.68
# 139                              NaN                      26.87
# 140                              NaN                      22.45
# 141                              NaN                      36.80
# 142                              NaN                      30.39
# 143                              NaN                      28.50
# 144                              NaN                      40.95
# 145                              NaN                      29.11
# 146                              NaN                      36.20
# 147                              NaN                      29.67
# 148                              NaN                      33.40
# 149                              NaN                      31.86
# 150                              NaN                      30.14
# 151                              NaN                      34.62
# 161                              NaN                        NaN
# ..                               ...                        ...
# 493                              NaN                        NaN
# 579                              NaN                        NaN
# 580                              NaN                        NaN
# 581                             2.43                        NaN
# 582                             2.74                        NaN
# 583                              NaN                        NaN
# 584                             2.38                        NaN
# 585                              NaN                        NaN
# 586                              NaN                        NaN
# 587                              NaN                       3.45
# 588                              NaN                        NaN
# 589                             2.77                        NaN
# 590                             2.91                        NaN
# 591                             3.70                        NaN
# 592                             3.40                        NaN
# 593                             2.85                       2.73
# 594                             3.64                        NaN
# 595                              NaN                        NaN
# 596                             2.87                        NaN
# 597                             2.28                        NaN
# 598                              NaN                        NaN
# 599                              NaN                       3.21
# 600                              NaN                        NaN
# 601                              NaN                        NaN
# 602                              NaN                        NaN
# 603                             3.42                        NaN
# 604                              NaN                        NaN
# 605                             2.20                       2.25
# 606                              NaN                        NaN
# 607                              NaN                        NaN
#
#      symptom:Aphonia  symptom:Asphyxia  symptom:Atheroma  \
# 123            64.27               NaN               NaN
# 124            50.26               NaN               NaN
# 125            36.37               NaN               NaN
# 126            28.45               NaN               NaN
# 127            23.07               NaN               NaN
# 128            23.21               NaN               NaN
# 129            17.34               NaN               NaN
# 130            22.00               NaN               NaN
# 131              NaN               NaN               NaN
# 132            16.99               NaN               NaN
# 133              NaN               NaN               NaN
# 134            20.45               NaN               NaN
# 135            14.29               NaN               NaN
# 136            13.62               NaN               NaN
# 137            15.82               NaN               NaN
# 138            19.55               NaN               NaN
# 139            20.46               NaN               NaN
# 140            21.55               NaN               NaN
# 141            22.73               NaN               NaN
# 142            24.78               NaN               NaN
# 143            25.80               NaN               NaN
# 144            32.11               NaN               NaN
# 145            16.30               NaN               NaN
# 146            17.40               NaN               NaN
# 147            27.25               NaN               NaN
# 148            23.35               NaN               NaN
# 149            16.07               NaN               NaN
# 150            23.35               NaN               NaN
# 151            22.36               NaN               NaN
# 161            42.41               NaN               NaN
# ..               ...               ...               ...
# 493             6.96              7.19             12.60
# 579             3.37              2.91              2.85
# 580             3.52              4.17              2.47
# 581              NaN              3.28              5.03
# 582             2.25              3.23               NaN
# 583              NaN              3.82              4.53
# 584              NaN              5.28              2.69
# 585              NaN              3.73              3.34
# 586              NaN              4.58              3.52
# 587              NaN              3.17              3.17
# 588              NaN               NaN              2.90
# 589              NaN               NaN              2.47
# 590              NaN              6.00               NaN
# 591              NaN             22.76              3.35
# 592              NaN              7.05              2.75
# 593              NaN              6.47              3.27
# 594              NaN               NaN              2.52
# 595              NaN              4.50               NaN
# 596              NaN              3.79              2.76
# 597              NaN              3.60              2.97
# 598              NaN              4.18              2.41
# 599              NaN              4.24              3.15
# 600              NaN               NaN              2.51
# 601              NaN              3.59              2.91
# 602              NaN              5.17              2.98
# 603              NaN              3.75              2.93
# 604              NaN              5.08              3.46
# 605              NaN              4.02               NaN
# 606              NaN              4.04              3.71
# 607              NaN              2.90              5.53
#
#      symptom:Auditory hallucination  ...  symptom:Rumination  \
# 123                             NaN  ...                 NaN
# 124                             NaN  ...                 NaN
# 125                             NaN  ...                 NaN
# 126                             NaN  ...                 NaN
# 127                             NaN  ...                 NaN
# 128                             NaN  ...                 NaN
# 129                             NaN  ...                 NaN
# 130                             NaN  ...                 NaN
# 131                             NaN  ...                 NaN
# 132                             NaN  ...                 NaN
# 133                             NaN  ...                 NaN
# 134                             NaN  ...                 NaN
# 135                             NaN  ...                 NaN
# 136                             NaN  ...                 NaN
# 137                             NaN  ...                 NaN
# 138                             NaN  ...                 NaN
# 139                             NaN  ...                 NaN
# 140                             NaN  ...                 NaN
# 141                             NaN  ...                 NaN
# 142                             NaN  ...                 NaN
# 143                             NaN  ...                 NaN
# 144                             NaN  ...                 NaN
# 145                             NaN  ...                 NaN
# 146                             NaN  ...                 NaN
# 147                             NaN  ...                 NaN
# 148                             NaN  ...                 NaN
# 149                             NaN  ...                 NaN
# 150                             NaN  ...                 NaN
# 151                             NaN  ...                 NaN
# 161                             NaN  ...                 NaN
# ..                              ...  ...                 ...
# 493                            6.74  ...                7.30
# 579                             NaN  ...                2.74
# 580                             NaN  ...                 NaN
# 581                            2.60  ...                3.79
# 582                             NaN  ...                2.25
# 583                             NaN  ...                3.22
# 584                             NaN  ...                2.85
# 585                             NaN  ...                2.19
# 586                             NaN  ...                2.74
# 587                            2.83  ...                3.45
# 588                            2.85  ...                2.79
# 589                             NaN  ...                3.95
# 590                             NaN  ...                 NaN
# 591                            2.63  ...                3.17
# 592                             NaN  ...                 NaN
# 593                             NaN  ...                 NaN
# 594                            3.05  ...                 NaN
# 595                            2.52  ...                2.46
# 596                            2.53  ...                2.93
# 597                            2.86  ...                 NaN
# 598                            2.87  ...                2.81
# 599                             NaN  ...                3.15
# 600                            2.57  ...                 NaN
# 601                            2.34  ...                 NaN
# 602                            2.69  ...                2.53
# 603                            4.53  ...                 NaN
# 604                             NaN  ...                2.85
# 605                            2.42  ...                2.86
# 606                            3.61  ...                3.88
# 607                            2.74  ...                2.24
#
#      symptom:Shallow breathing  symptom:Stridor  symptom:Subdural hematoma  \
# 123                      49.58              NaN                        NaN
# 124                      83.77              NaN                        NaN
# 125                      73.87              NaN                        NaN
# 126                      60.19              NaN                        NaN
# 127                      44.50              NaN                        NaN
# 128                      42.11              NaN                        NaN
# 129                      34.13              NaN                        NaN
# 130                      30.53              NaN                        NaN
# 131                      28.25              NaN                        NaN
# 132                      31.71              NaN                        NaN
# 133                      22.45              NaN                        NaN
# 134                      36.16              NaN                        NaN
# 135                      25.91              NaN                        NaN
# 136                      29.31              NaN                        NaN
# 137                      29.56              NaN                        NaN
# 138                      34.89              NaN                        NaN
# 139                      31.45              NaN                        NaN
# 140                      35.62              NaN                        NaN
# 141                      37.09              NaN                        NaN
# 142                      41.01              NaN                        NaN
# 143                      33.00              NaN                        NaN
# 144                      34.47              NaN                        NaN
# 145                      29.69              NaN                        NaN
# 146                      36.20              NaN                        NaN
# 147                      20.50              NaN                        NaN
# 148                      39.92              NaN                        NaN
# 149                      28.05              NaN                        NaN
# 150                      33.13              NaN                        NaN
# 151                      36.26              NaN                        NaN
# 161                        NaN              NaN                        NaN
# ..                         ...              ...                        ...
# 493                       5.42             8.96                      14.70
# 579                       3.77             2.91                       4.96
# 580                       5.05             4.17                       3.88
# 581                       4.63             3.22                        NaN
# 582                       3.45             3.34                       3.78
# 583                       2.95             2.40                       2.84
# 584                        NaN              NaN                       2.91
# 585                       2.19             2.36                       4.66
# 586                       2.68              NaN                       3.02
# 587                        NaN              NaN                       3.79
# 588                        NaN              NaN                       3.81
# 589                        NaN              NaN                        NaN
# 590                        NaN              NaN                       2.85
# 591                        NaN              NaN                       3.76
# 592                        NaN              NaN                       3.52
# 593                        NaN              NaN                       5.05
# 594                        NaN              NaN                       3.76
# 595                        NaN              NaN                       3.72
# 596                        NaN              NaN                       3.85
# 597                        NaN              NaN                       4.57
# 598                        NaN              NaN                       3.67
# 599                        NaN              NaN                       2.98
# 600                        NaN              NaN                       4.45
# 601                       2.97              NaN                       2.74
# 602                        NaN              NaN                       3.76
# 603                        NaN              NaN                       2.82
# 604                       2.90              NaN                       2.85
# 605                       2.20             2.48                       5.23
# 606                        NaN             2.57                       3.22
# 607                        NaN             2.74                       4.32
#
#      symptom:Tenderness  symptom:Trichoptilosis  symptom:Urinary urgency  \
# 123                 NaN                     NaN                      NaN
# 124                 NaN                     NaN                      NaN
# 125                 NaN                     NaN                      NaN
# 126                 NaN                     NaN                      NaN
# 127                 NaN                     NaN                      NaN
# 128                 NaN                     NaN                      NaN
# 129                 NaN                     NaN                      NaN
# 130                 NaN                     NaN                      NaN
# 131                 NaN                     NaN                      NaN
# 132                 NaN                     NaN                      NaN
# 133                 NaN                     NaN                      NaN
# 134                 NaN                     NaN                      NaN
# 135                 NaN                     NaN                      NaN
# 136                 NaN                     NaN                      NaN
# 137                 NaN                     NaN                      NaN
# 138                 NaN                     NaN                      NaN
# 139                 NaN                     NaN                      NaN
# 140                 NaN                     NaN                      NaN
# 141                 NaN                     NaN                      NaN
# 142                 NaN                     NaN                      NaN
# 143                 NaN                     NaN                      NaN
# 144                 NaN                     NaN                      NaN
# 145                 NaN                     NaN                      NaN
# 146                 NaN                     NaN                      NaN
# 147                 NaN                     NaN                      NaN
# 148                 NaN                     NaN                      NaN
# 149                 NaN                     NaN                      NaN
# 150                 NaN                     NaN                      NaN
# 151                 NaN                     NaN                      NaN
# 161                 NaN                     NaN                      NaN
# ..                  ...                     ...                      ...
# 493               13.93                    9.95                     8.18
# 579                3.54                    2.85                      NaN
# 580                3.76                    3.35                      NaN
# 581                2.77                    3.33                      NaN
# 582                2.80                    4.88                      NaN
# 583                3.93                    3.06                      NaN
# 584                3.22                    4.28                      NaN
# 585                3.40                    3.18                     2.63
# 586                4.81                    3.41                     2.52
# 587                3.90                    3.96                      NaN
# 588                2.90                    3.64                      NaN
# 589                3.65                    2.42                      NaN
# 590                4.48                    3.57                      NaN
# 591                3.23                    3.17                     2.57
# 592                2.93                    3.64                      NaN
# 593                2.91                    2.67                      NaN
# 594                3.70                     NaN                      NaN
# 595                3.90                    2.82                      NaN
# 596                 NaN                     NaN                     2.59
# 597                2.57                    2.97                      NaN
# 598                3.61                    2.81                      NaN
# 599                4.36                    2.75                     2.41
# 600                3.65                    2.97                     2.40
# 601                3.54                    3.77                      NaN
# 602                3.42                    3.71                     2.42
# 603                3.98                    2.26                      NaN
# 604                3.07                    2.57                      NaN
# 605                4.29                     NaN                      NaN
# 606                3.93                    3.06                     2.68
# 607                3.28                    3.17                      NaN
#
#      symptom:Ventricular fibrillation  symptom:Viral pneumonia  \
# 123                               NaN                   100.00
# 124                               NaN                    88.60
# 125                               NaN                    70.51
# 126                               NaN                    46.78
# 127                               NaN                    28.57
# 128                               NaN                    14.04
# 129                               NaN                    24.92
# 130                               NaN                    22.83
# 131                               NaN                    15.66
# 132                               NaN                      NaN
# 133                               NaN                      NaN
# 134                               NaN                      NaN
# 135                               NaN                      NaN
# 136                               NaN                    17.47
# 137                               NaN                    18.21
# 138                               NaN                      NaN
# 139                               NaN                      NaN
# 140                               NaN                    18.56
# 141                               NaN                    17.95
# 142                               NaN                    16.52
# 143                               NaN                    14.10
# 144                               NaN                      NaN
# 145                               NaN                      NaN
# 146                               NaN                    19.93
# 147                               NaN                    11.33
# 148                               NaN                    13.04
# 149                               NaN                    18.52
# 150                               NaN                      NaN
# 151                               NaN                    14.99
# 161                               NaN                   100.00
# ..                                ...                      ...
# 493                             13.16                     6.86
# 579                              2.34                     8.79
# 580                               NaN                     9.57
# 581                               NaN                     8.31
# 582                               NaN                     5.43
# 583                              2.62                      NaN
# 584                               NaN                     4.01
# 585                              2.36                      NaN
# 586                               NaN                      NaN
# 587                               NaN                      NaN
# 588                              2.73                      NaN
# 589                              2.77                      NaN
# 590                               NaN                      NaN
# 591                              2.45                      NaN
# 592                               NaN                      NaN
# 593                               NaN                      NaN
# 594                              3.11                      NaN
# 595                               NaN                      NaN
# 596                              2.87                      NaN
# 597                              2.97                      NaN
# 598                              2.35                      NaN
# 599                               NaN                      NaN
# 600                               NaN                      NaN
# 601                              2.57                      NaN
# 602                               NaN                      NaN
# 603                              2.48                      NaN
# 604                               NaN                      NaN
# 605                               NaN                      NaN
# 606                               NaN                      NaN
# 607                              3.23                      NaN
#
#      hospitalized_new
# 123               0.0
# 124               0.0
# 125              12.0
# 126               7.0
# 127              25.0
# 128               7.0
# 129              17.0
# 130               4.0
# 131               9.0
# 132               1.0
# 133               2.0
# 134              -1.0
# 135               0.0
# 136               6.0
# 137               7.0
# 138              14.0
# 139               8.0
# 140               7.0
# 141              15.0
# 142              21.0
# 143              33.0
# 144              43.0
# 145              42.0
# 146              98.0
# 147             120.0
# 148              95.0
# 149              43.0
# 150              91.0
# 151              76.0
# 161               0.0
# ..                ...
# 493             185.0
# 579               0.0
# 580               0.0
# 581              15.0
# 582               8.0
# 583              17.0
# 584              10.0
# 585               4.0
# 586               6.0
# 587               5.0
# 588               5.0
# 589               8.0
# 590               7.0
# 591               5.0
# 592               3.0
# 593               7.0
# 594              12.0
# 595               7.0
# 596               5.0
# 597              19.0
# 598              15.0
# 599               9.0
# 600              10.0
# 601              14.0
# 602              16.0
# 603               8.0
# 604               4.0
# 605               9.0
# 606              15.0
# 607              19.0
#
# [319 rows x 65 columns]

# %%
# Convert merged dataset into a numpy array
myarray = pd.DataFrame(st_df2).to_numpy()

# %% [markdown]
# ## End of Task 1

# %% [markdown]
# # Task 3: Supervised Learning

# %%
#Imports
from sklearn import neighbors
from sklearn import tree
from  sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Data preprocessing

# %%
#replace NaN values to be 0's
myarray[pd.isnull(myarray)] = 0
print(myarray.shape)

#data_r is sorted based on regions
data_r = myarray
#data_t is sorted based on time
data_t = np.array(sorted(myarray,key = lambda x: x[2]))

#split the region-based data to be regions, features, and label
regions_r = data_r[:,0]
features_r = data_r[:,3:-1].astype(float)
label_r = data_r[:,-1].astype(int)
#split the time-based data to be time, features, and label
time_t = data_t[:,2]
features_t = data_t[:,3:-1].astype(float)
label_t = data_t[:,-1].astype(int)
# Out:
# (319, 65)

# %% [markdown]
# ## Region-based cross-validation (5-fold)

# %%
#split the region-based data into 5 folds based on regions
from sklearn.model_selection import GroupKFold
gkf = GroupKFold(n_splits=5)
#specify the group indices by regions
groups = regions_r
for i in range(groups.shape[0]):
    if groups[i] == 'Hawaii' or groups[i] ==  'Idaho':
        groups[i] = 1
    elif groups[i] == 'Maine' or groups[i] ==  'Montana':
        groups[i] = 2
    elif groups[i] ==  'North Dakota' or groups[i] ==  'Nebraska':
        groups[i] = 3
    elif groups[i] ==  'New Hampshire' or groups[i] ==  'New Mexico':
        groups[i] = 4
    else:
        groups[i] = 5

# %% [markdown]
# ### KNN (region-based validation)

# %%
#plot cross-validated MSE error of KNN with respect to different values of k
import matplotlib.pyplot as plt
# %matplotlib notebook
k_range_r = range(1, 10)
k_scores_r = []
for k in k_range_r:
    knn_r = neighbors.KNeighborsRegressor(n_neighbors=k)
    loss = abs(cross_val_score(knn_r, features_r,label_r, cv=gkf.split(features_r,label_r, groups), scoring='neg_mean_squared_error'))
    k_scores_r.append(loss.mean())
plt.plot(k_range_r, k_scores_r)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated MSE')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#k=8 leads to the least MSE, whcih can represent performance of KNN
knn_r_error = k_scores_r[7]
print(knn_r_error)
# Out:
# 8794.266271551725

# %% [markdown]
# ### Decision tree (region-based validation)

# %%
#calculate cross-validated MSE of decision tree
dt_r = tree.DecisionTreeRegressor(random_state=1)
loss = abs(cross_val_score(dt_r, features_r, label_r, cv = gkf.split(features_r,label_r, groups), scoring='neg_mean_squared_error'))
dt_r_error = loss.mean()
print(dt_r_error)
# Out:
# 10613.914942528736

# %% [markdown]
# ## Time-based validation

# %%
#split the data into train and test sets based on the timepoint '2020-08-10'
#data before '2020-08-10' are in train set and the rest are in test set
#time_t[242] is the first '2020-08-10' which is the splitting point
features_t_train = features_t[0:241]
label_t_train = label_t[0:241]
features_t_test = features_t[241:320]
label_t_test = label_t[241:320]

# %% [markdown]
# ### KNN (time-based validation)

# %%
#plot validated MSE error of KNN with respect to different values of k
import matplotlib.pyplot as plt
# %matplotlib notebook
k_range_t = range(1, 11)
k_scores_t= []
for k in k_range_t:
    knn_t = neighbors.KNeighborsRegressor(n_neighbors = k)
    knn_t.fit(features_t_train, label_t_train)
    label_t_pred_knn = knn_t.predict(features_t_test)
    loss = mean_squared_error(label_t_test, label_t_pred_knn)
    k_scores_t.append(loss)
plt.plot(k_range_t, k_scores_t)
plt.xlabel('Value of K for KNN')
plt.ylabel('Validated MSE')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#k=7 leads to the least MSE, whcih can represent performance of KNN
knn_t_error = k_scores_t[6]
print(knn_t_error)
# Out:
# 2876.8877551020414

# %% [markdown]
# ### Decision tree (time-based validation)

# %%
#calculate validated MSE of decision tree
dt_t = tree.DecisionTreeRegressor(random_state=1)
dt_t.fit(features_t_train, label_t_train)
label_t_pred_dt = dt_t.predict(features_t_test)
dt_t_error = mean_squared_error(label_t_test, label_t_pred_dt)
print(dt_t_error)
# Out:
# 5343.089743589743

# %% [markdown]
# ## Optional part: learn seperate model for each region with time-based validation

# %% [markdown]
# ### KNN (regional models with time-based validation)

# %%
#plot average validated KNN MSE error of all regions with respect to different values of k
import matplotlib.pyplot as plt
# %matplotlib notebook
k_range_regional = range(1, 11)
k_scores_regional= []

for k in k_range_regional:
    regional_MSE_knn = []
    for i in range(0,groups.shape[0],29):
        #each iteration deal with data from one city
        regional_features = features_r[i:i+29]
        regional_label = label_r[i:i+29]
        #split the data into train and test sets based on the timepoint 2020-08-10
        #data before 2020-08-10 are in train set and the rest are in test set
        #for data of each region, the 24th. datum is of '2020-08-10' which is the splitting point
        regional_features_train = regional_features[0:23]
        regional_label_train = regional_label[0:23]
        regional_features_test = regional_features[23:29]
        regional_label_test = regional_label[23:29]
        #calculate the KNN MSE of the city of this iteration
        knn = neighbors.KNeighborsRegressor(n_neighbors = k)
        knn.fit(regional_features_train, regional_label_train)
        regional_label_pred_knn = knn.predict(regional_features_test)
        loss_knn = mean_squared_error(regional_label_test, regional_label_pred_knn)
        regional_MSE_knn.append(loss_knn)
    #append the average validated MSE of the current k
    regional_MSE_knn = np.array(regional_MSE_knn)
    k_scores_regional.append(regional_MSE_knn.mean())

plt.plot(k_range_regional, k_scores_regional)
plt.xlabel('Value of K for KNN')
plt.ylabel('Average Validated MSE')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#k=10 leads to the least average MSE, whcih can represent performance of KNN
knn_regional_error = k_scores_regional[9]
print(knn_regional_error)
# Out:
# 2648.1472727272726

# %% [markdown]
# ### Decision tree (regional models with time-based validation)

# %%
#calculate the average validated decision tree MSE error of all regions
regional_MSE_dt = []
for i in range(0,groups.shape[0],29):
    #each iteration deal with data from one city
    regional_features = features_r[i:i+29]
    regional_label = label_r[i:i+29]
    #split the data into train and test sets based on the timepoint 2020-08-10
    #data before 2020-08-10 are in train set and the rest are in test set
    #for data of each region, the 24th. datum is of '2020-08-10' which is the splitting point
    regional_features_train = regional_features[0:23]
    regional_label_train = regional_label[0:23]
    regional_features_test = regional_features[23:29]
    regional_label_test = regional_label[23:29]
    #calculate the decision tree MSE of the city of this iteration
    dt = tree.DecisionTreeRegressor(random_state=1)
    dt.fit(regional_features_train, regional_label_train)
    regional_label_pred_dt = dt.predict(regional_features_test)
    loss_dt = mean_squared_error(regional_label_test, regional_label_pred_dt)
    regional_MSE_dt.append(loss_dt)
    
regional_MSE_dt = np.array(regional_MSE_dt)
dt_regional_error = regional_MSE_dt.mean()
print(dt_regional_error)
# Out:
# 3384.484848484848
